# %% [markdown]
# # Create station pairs with rebalance counts
# Data will be used to draw arcs via pydeck + deck.gl

# %%
import pandas as pd
import pydeck as pdk
import dash_deck
import os

# import our helpers module. appending parent directory ("..") to sys.path might be necessary for helpers to be imported on some systems
import sys

sys.path.insert(0, "..")
import helpers

# %%
DATA_DIR = "data/"
STATIONS_DIR = DATA_DIR + "stations/"
REBALANCE_DIR = DATA_DIR + "rebalance_parquet/"
STATIONS_PAIRS_DIR = DATA_DIR + "stations-pairs/"

TRIP_YEAR = 2019

# %%
# read stations
stations = pd.read_csv(STATIONS_DIR + "stations.csv", index_col=0)
stations["stationid"] = stations["stationid"].astype("int64")
stations.drop(
    ["capacity", "neighbourhood", "boro", "zipcode", "elevation_ft"],
    axis=1,
    inplace=True,
)
stations
# Out:
#       stationid                                     stationname   latitude  \
# 0           455                                 1 Ave & E 44 St  40.750020
# 1           434                                 9 Ave & W 18 St  40.743174
# 2           491                            E 24 St & Park Ave S  40.740964
# 3           384                         Fulton St & Waverly Ave  40.683178
# 4           474                                 5 Ave & E 29 St  40.745168
# ...         ...                                             ...        ...
# 1425       3685  Prospect Park - 5 Year Anniversary Celebration  40.660652
# 1426       3695                                  E 5 St & 2 Ave  40.726870
# 1427       3700                                 E 87 St & 3 Ave  40.779406
# 1428       3805                              E 80 St & Park Ave  40.776173
# 1429       3747                                 E 84 St & 3 Ave  40.777554
#
#       longitude
# 0    -73.969053
# 1    -74.003664
# 2    -73.986022
# 3    -73.965964
# 4    -73.986831
# ...         ...
# 1425 -73.964590
# 1426 -73.989190
# 1427 -73.953336
# 1428 -73.959757
# 1429 -73.955128
#
# [1430 rows x 4 columns]

# %%
rebpairs = pd.read_parquet(
    REBALANCE_DIR + "rebalance_pairs" + helpers.PARQUET_EXTENSION, engine="pyarrow"
)
rebpairs = rebpairs.loc[rebpairs.rebal_year == TRIP_YEAR].drop("rebal_year", axis=1)
rebpairs["stationid_from"] = rebpairs["stationid_from"].astype("int")
rebpairs["stationid_to"] = rebpairs["stationid_to"].astype("int")
rebpairs = rebpairs[["stationid_from", "stationid_to", "rebal_count"]]
rebpairs = rebpairs.sort_values(by="rebal_count", ascending=False).head(100)
rebpairs
# Out:
#      stationid_from  stationid_to  rebal_count
# 42              445           394         1807
# 57             3263           432         1531
# 68              445           433         1307
# 71             3443          3158         1276
# 73              445          3718         1226
# ..              ...           ...          ...
# 726             335           432          292
# 735             426          3177          289
# 741            3718           317          286
# 745             265           473          285
# 751             394          3733          284
#
# [100 rows x 3 columns]

# %%
_from = pd.merge(
    left=rebpairs,
    right=stations,
    left_on="stationid_from",
    right_on="stationid",
    how="left",
)
_from.drop("stationid", axis=1, inplace=True)
_from.rename(
    columns={
        "latitude": "latitude_from",
        "longitude": "longitude_from",
        "stationname": "stationname_from",
    },
    inplace=True,
)
_from
# Out:
#     stationid_from  stationid_to  rebal_count          stationname_from  \
# 0              445           394         1807        E 10 St & Avenue A
# 1             3263           432         1531    Cooper Square & E 7 St
# 2              445           433         1307        E 10 St & Avenue A
# 3             3443          3158         1276           W 52 St & 6 Ave
# 4              445          3718         1226        E 10 St & Avenue A
# ..             ...           ...          ...                       ...
# 95             335           432          292  Washington Pl & Broadway
# 96             426          3177          289     West St & Chambers St
# 97            3718           317          286        E 11 St & Avenue B
# 98             265           473          285  Stanton St & Chrystie St
# 99             394          3733          284         E 9 St & Avenue C
#
#     latitude_from  longitude_from
# 0       40.727408      -73.981420
# 1       40.729236      -73.990868
# 2       40.727408      -73.981420
# 3       40.761330      -73.979820
# 4       40.727408      -73.981420
# ..            ...             ...
# 95      40.729039      -73.994046
# 96      40.717548      -74.013221
# 97      40.727464      -73.979504
# 98      40.722293      -73.991475
# 99      40.725213      -73.977688
#
# [100 rows x 6 columns]

# %%
_to = pd.merge(
    left=_from, right=stations, left_on="stationid_to", right_on="stationid", how="left"
)
_to.rename(
    columns={
        "latitude": "latitude_to",
        "longitude": "longitude_to",
        "stationname": "stationname_to",
    },
    inplace=True,
)
_to.insert(0, "rebal_count", _to.pop("rebal_count"))
_to
# Out:
#     rebal_count  stationid_from  stationid_to          stationname_from  \
# 0          1807             445           394        E 10 St & Avenue A
# 1          1531            3263           432    Cooper Square & E 7 St
# 2          1307             445           433        E 10 St & Avenue A
# 3          1276            3443          3158           W 52 St & 6 Ave
# 4          1226             445          3718        E 10 St & Avenue A
# ..          ...             ...           ...                       ...
# 95          292             335           432  Washington Pl & Broadway
# 96          289             426          3177     West St & Chambers St
# 97          286            3718           317        E 11 St & Avenue B
# 98          285             265           473  Stanton St & Chrystie St
# 99          284             394          3733         E 9 St & Avenue C
#
#     latitude_from  longitude_from  stationid              stationname_to  \
# 0       40.727408      -73.981420        394           E 9 St & Avenue C
# 1       40.729236      -73.990868        432           E 7 St & Avenue A
# 2       40.727408      -73.981420        433          E 13 St & Avenue A
# 3       40.761330      -73.979820       3158          W 63 St & Broadway
# 4       40.727408      -73.981420       3718          E 11 St & Avenue B
# ..            ...             ...        ...                         ...
# 95      40.729039      -73.994046        432           E 7 St & Avenue A
# 96      40.717548      -74.013221       3177          W 84 St & Broadway
# 97      40.727464      -73.979504        317           E 6 St & Avenue B
# 98      40.722293      -73.991475        473  Rivington St & Chrystie St
# 99      40.725213      -73.977688       3733          Avenue C & E 18 St
#
#     latitude_to  longitude_to
# 0     40.725213    -73.977688
# 1     40.726218    -73.983799
# 2     40.729554    -73.980572
# 3     40.771639    -73.982614
# 4     40.727464    -73.979504
# ..          ...           ...
# 95    40.726218    -73.983799
# 96    40.786795    -73.977112
# 97    40.724537    -73.981854
# 98    40.721101    -73.991925
# 99    40.730563    -73.973984
#
# [100 rows x 10 columns]

# %%
station_pairs = _to
station_pairs
# Out:
#     rebal_count  stationid_from  stationid_to          stationname_from  \
# 0          1807             445           394        E 10 St & Avenue A
# 1          1531            3263           432    Cooper Square & E 7 St
# 2          1307             445           433        E 10 St & Avenue A
# 3          1276            3443          3158           W 52 St & 6 Ave
# 4          1226             445          3718        E 10 St & Avenue A
# ..          ...             ...           ...                       ...
# 95          292             335           432  Washington Pl & Broadway
# 96          289             426          3177     West St & Chambers St
# 97          286            3718           317        E 11 St & Avenue B
# 98          285             265           473  Stanton St & Chrystie St
# 99          284             394          3733         E 9 St & Avenue C
#
#     latitude_from  longitude_from  stationid              stationname_to  \
# 0       40.727408      -73.981420        394           E 9 St & Avenue C
# 1       40.729236      -73.990868        432           E 7 St & Avenue A
# 2       40.727408      -73.981420        433          E 13 St & Avenue A
# 3       40.761330      -73.979820       3158          W 63 St & Broadway
# 4       40.727408      -73.981420       3718          E 11 St & Avenue B
# ..            ...             ...        ...                         ...
# 95      40.729039      -73.994046        432           E 7 St & Avenue A
# 96      40.717548      -74.013221       3177          W 84 St & Broadway
# 97      40.727464      -73.979504        317           E 6 St & Avenue B
# 98      40.722293      -73.991475        473  Rivington St & Chrystie St
# 99      40.725213      -73.977688       3733          Avenue C & E 18 St
#
#     latitude_to  longitude_to
# 0     40.725213    -73.977688
# 1     40.726218    -73.983799
# 2     40.729554    -73.980572
# 3     40.771639    -73.982614
# 4     40.727464    -73.979504
# ..          ...           ...
# 95    40.726218    -73.983799
# 96    40.786795    -73.977112
# 97    40.724537    -73.981854
# 98    40.721101    -73.991925
# 99    40.730563    -73.973984
#
# [100 rows x 10 columns]

# %%
if not os.path.exists(STATIONS_PAIRS_DIR):
    os.mkdir(STATIONS_PAIRS_DIR)

station_pairs.to_csv(STATIONS_PAIRS_DIR + "pairs" + helpers.CSV_EXTENSION)

# %%
GREEN_RGB = [0, 255, 0, 40]
RED_RGB = [240, 100, 0, 40]
TOOLTIP_TEXT = {
    "html": "{rebal_count} bikes to be rebalanced <br/>from {station_name_from} to {station_name_to}"
}
token = open(".mapbox_token").read()

# %%
# Specify a deck.gl ArcLayer
arc_layer = pdk.Layer(
    "ArcLayer",
    data=station_pairs,
    get_width="S000 * 10",
    # get_width="rebal_count",
    get_source_position=["longitude_from", "latitude_from"],
    get_target_position=["longitude_to", "latitude_to"],
    get_tilt=10,
    get_source_color=RED_RGB,
    get_target_color=GREEN_RGB,
    pickable=True,
    auto_highlight=True,
)

# %%
view_state = pdk.ViewState(
    latitude=station_pairs.latitude_to.mean(),
    longitude=station_pairs.longitude_to.mean(),
    bearing=0,
    pitch=30,
    zoom=12,
)  # TODO fix
r = pdk.Deck(
    arc_layer, initial_view_state=view_state, tooltip=TOOLTIP_TEXT, map_style="dark"
)
r.to_html("arc_layer.html")

# rv = dash_deck.DeckGL(r.to_json(),style = {'height' : '100%',"position": 'relative'},
#                       id='rebalancing-strategy-graphic',
#                       mapboxKey=mapbox_key)
# Out:
#         <iframe
#             width="100%"
#             height=500
#             frameborder="0"
#             srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
#   &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;title&gt;pydeck&lt;/title&gt;
#         &lt;script src=&quot;https://api.tiles.mapbox.com/mapbox-gl-js/v1.13.0/mapbox-gl.js&quot;&gt;&lt;/script&gt;
#         &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot; /&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot; /&gt;
#     &lt;script src=&#x27;https://cdn.jsdelivr.net/npm/@deck.gl/jupyter-widget@~8.5.*/dist/index.js&#x27;&gt;&lt;/script&gt;
#     &lt;style&gt;
#     body {
#   margin: 0;
#   padding: 0;
#   overflow: hidden;
# }
#
# #deck-map-container {
#   width: 100%;
#   height: 100%;
#   background-color: black;
# }
#
# #map {
#   pointer-events: none;
#   height: 100%;
#   width: 100%;
#   position: absolute;
#   z-index: 1;
# }
#
# #deckgl-overlay {
#   z-index: 2;
#   background: none;
# }
#
# #deck-map-wrapper {
#   width: 100%;
#   height: 100%;
# }
#
# #deck-container {
#   width: 100vw;
#   height: 100vh;
# }
#     &lt;/style&gt;
#   &lt;/head&gt;
#   &lt;body&gt;
#     &lt;div id=&quot;deck-container&quot;&gt;
#     &lt;/div&gt;
#   &lt;/body&gt;
#   &lt;script&gt;
#     const jsonInput = {&quot;initialViewState&quot;: {&quot;bearing&quot;: 0, &quot;latitude&quot;: 40.73632544404239, &quot;longitude&quot;: -73.9804731782877, &quot;pitch&quot;: 30, &quot;zoom&quot;: 12}, &quot;layers&quot;: [{&quot;@@type&quot;: &quot;ArcLayer&quot;, &quot;autoHighlight&quot;: true, &quot;data&quot;: [{&quot;latitude_from&quot;: 40.72740794, &quot;latitude_to&quot;: 40.72521311, &quot;longitude_from&quot;: -73.98142006, &quot;longitude_to&quot;: -73.97768752, &quot;rebal_count&quot;: 1807, &quot;stationid&quot;: 394, &quot;stationid_from&quot;: 445, &quot;stationid_to&quot;: 394, &quot;stationname_from&quot;: &quot;E 10 St &amp; Avenue A&quot;, &quot;stationname_to&quot;: &quot;E 9 St &amp; Avenue C&quot;}, {&quot;latitude_from&quot;: 40.72923649910006, &quot;latitude_to&quot;: 40.72621788, &quot;longitude_from&quot;: -73.99086803197861, &quot;longitude_to&quot;: -73.98379855, &quot;rebal_count&quot;: 1531, &quot;stationid&quot;: 432, &quot;stationid_from&quot;: 3263, &quot;stationid_to&quot;: 432, &quot;stationname_from&quot;: &quot;Cooper Square &amp; E 7 St&quot;, &quot;stationname_to&quot;: &quot;E 7 St &amp; Avenue A&quot;}, {&quot;latitude_from&quot;: 40.72740794, &quot;latitude_to&quot;: 40.72955361, &quot;longitude_from&quot;: -73.98142006, &quot;longitude_to&quot;: -73.98057249, &quot;rebal_count&quot;: 1307, &quot;stationid&quot;: 433, &quot;stationid_from&quot;: 445, &quot;stationid_to&quot;: 433, &quot;stationname_from&quot;: &quot;E 10 St &amp; Avenue A&quot;, &quot;stationname_to&quot;: &quot;E 13 St &amp; Avenue A&quot;}, {&quot;latitude_from&quot;: 40.76132983124814, &quot;latitude_to&quot;: 40.77163851, &quot;longitude_from&quot;: -73.97982001304626, &quot;longitude_to&quot;: -73.98261428, &quot;rebal_count&quot;: 1276, &quot;stationid&quot;: 3158, &quot;stationid_from&quot;: 3443, &quot;stationid_to&quot;: 3158, &quot;stationname_from&quot;: &quot;W 52 St &amp; 6 Ave&quot;, &quot;stationname_to&quot;: &quot;W 63 St &amp; Broadway&quot;}, {&quot;latitude_from&quot;: 40.72740794, &quot;latitude_to&quot;: 40.72746420692392, &quot;longitude_from&quot;: -73.98142006, &quot;longitude_to&quot;: -73.97950418293476, &quot;rebal_count&quot;: 1226, &quot;stationid&quot;: 3718, &quot;stationid_from&quot;: 445, &quot;stationid_to&quot;: 3718, &quot;stationname_from&quot;: &quot;E 10 St &amp; Avenue A&quot;, &quot;stationname_to&quot;: &quot;E 11 St &amp; Avenue B&quot;}, {&quot;latitude_from&quot;: 40.7403432, &quot;latitude_to&quot;: 40.739445, &quot;longitude_from&quot;: -73.98955109, &quot;longitude_to&quot;: -73.976806, &quot;rebal_count&quot;: 1186, &quot;stationid&quot;: 2012, &quot;stationid_from&quot;: 402, &quot;stationid_to&quot;: 2012, &quot;stationname_from&quot;: &quot;Broadway &amp; E 22 St&quot;, &quot;stationname_to&quot;: &quot;E 27 St &amp; 1 Ave&quot;}, {&quot;latitude_from&quot;: 40.72923649910006, &quot;latitude_to&quot;: 40.72740794, &quot;longitude_from&quot;: -73.99086803197861, &quot;longitude_to&quot;: -73.98142006, &quot;rebal_count&quot;: 1183, &quot;stationid&quot;: 445, &quot;stationid_from&quot;: 3263, &quot;stationid_to&quot;: 445, &quot;stationname_from&quot;: &quot;Cooper Square &amp; E 7 St&quot;, &quot;stationname_to&quot;: &quot;E 10 St &amp; Avenue A&quot;}, {&quot;latitude_from&quot;: 40.7403432, &quot;latitude_to&quot;: 40.74286877312112, &quot;longitude_from&quot;: -73.98955109, &quot;longitude_to&quot;: -73.98918628692627, &quot;rebal_count&quot;: 1055, &quot;stationid&quot;: 3641, &quot;stationid_from&quot;: 402, &quot;stationid_to&quot;: 3641, &quot;stationname_from&quot;: &quot;Broadway &amp; E 22 St&quot;, &quot;stationname_to&quot;: &quot;Broadway &amp; W 25 St&quot;}, {&quot;latitude_from&quot;: 40.72743423, &quot;latitude_to&quot;: 40.72621788, &quot;longitude_from&quot;: -73.99379025, &quot;longitude_to&quot;: -73.98379855, &quot;rebal_count&quot;: 929, &quot;stationid&quot;: 432, &quot;stationid_from&quot;: 229, &quot;stationid_to&quot;: 432, &quot;sta ...

# %%
import dash
from dash import html

app = dash.Dash(__name__)

app.layout = html.Div(
    dash_deck.DeckGL(r.to_json(), id="deck-gl", tooltip=TOOLTIP_TEXT, mapboxKey=token)
)

app.run_server(debug=True, use_reloader=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
